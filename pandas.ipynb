# %%
# !pip install pandas

# %%
import pandas as pd

# %%
info = {

    "name":["rahul","ayush","tushar"],
    "CGPA":[9.5,7.5,8.5]
}
df=pd.DataFrame(info)
print(df)
# Out:
#      name  CGPA
# 0   rahul   9.5
# 1   ayush   7.5
# 2  tushar   8.5

# %%
import pandas as pd

# %%
s=pd.Series(["cat","dog","fox","iron"])
print(s)
# Out:
# 0     cat
# 1     dog
# 2     fox
# 3    iron
# dtype: object

# %%
import pandas as pd

# %%
s = pd.Series(["shyam","kaam","cat"])
print(s)
# Out:
# 0    shyam
# 1     kaam
# 2      cat
# dtype: object

# %%
k =pd.Series([1,2,3,4,5])
print(k)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
k = pd.Series([1,2,3],index=["adom","eve","bpb"])
print(k)
print(k["adom"])
print(k["eve"])
# Out:
# adom    1
# eve     2
# bpb     3
# dtype: int64
# 1
# 2

# %%
#data frame
import pandas as pd
info = {
    "name":['adom','bob','eve','alice'],
    "age":[24,25,6,3],
     "roll no.":[25,36,89,14]

}
df = pd.DataFrame(info)
print(df)
# Out:
#     name  age  roll no.
# 0   adom   24        25
# 1    bob   25        36
# 2    eve    6        89
# 3  alice    3        14

# %%
df = pd.DataFrame([["ram",45],["shyam",45],["shivam",19]],columns=["name","age"])
print(df)
# Out:
#      name  age
# 0     ram   45
# 1   shyam   45
# 2  shivam   19

# %% [markdown]
# import numpy as np
#
# np_arr = np.array([[1,2,3],[4,5,6]])
# df = pd.dataframe(np_arr,columns=["a","b","c"])
# print(df)

# %%
import numpy as np

np_arr = np.array([[1,2,3],[4,5,6]]) 
df = pd.DataFrame(np_arr,columns=["a","b","c"]) 
print(df)
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %% [raw]
# # work with csv data

# %%
# work with csv data
df=pd.read_csv("employee_data.csv")
print(df,type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.core.frame.DataFrame'>

# %%
# work with json data
df=pd.read_csv("employee_data.csv")
print(df,type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.core.frame.DataFrame'>
