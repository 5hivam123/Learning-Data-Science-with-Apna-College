# %%
hello("shivam
")
# Out:
#   Cell In[1], line 1
#     hello("shivam
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello shivam
")
# Out:
#   Cell In[2], line 1
#     print("hello shivam
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("hello shivam")
# Out:
# hello shivam

# %%
print("hello shivam"
     )
# Out:
# hello shivam
